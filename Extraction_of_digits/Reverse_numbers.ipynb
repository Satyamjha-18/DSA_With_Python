# %%
n = 4398343

num = n

while num >0:
    last_digit = num%10
    print(last_digit)

    num=num//10

print(num)
# Out:
# 3
# 4
# 3
# 8
# 9
# 3
# 4
# 0

# %%
n = 4398343

num = n

while num >0:
    last_digit = num%10
    print(last_digit,end=' ')

    num=num//10

print(num)
# Out:
# 3 4 3 8 9 3 4 0
