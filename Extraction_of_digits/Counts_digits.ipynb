# %%
n =5439

# %%
num =n
count =0
while num >0:
    count+=1
    num=num//10

print ("Digit:",count)
# Out:
# Digit: 4

# %% [markdown]
# ### Method:2

# %%
from math import *

# %%
def count_digits(num):
    return int(log10(num)+1)

# %%
count_digits(12423)
# Out:
# 5
