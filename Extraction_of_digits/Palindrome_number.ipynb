# %%
n = 24233223

num =n
result =0

while num >0:
    last_digit = num%10
    result= (result*10)+last_digit
    num= num//10

if n == result:
    print("Num is palindrome")

else:
    print("Not a Palindrom")
# Out:
# Not a Palindrom

# %%
n = 23432

num =n
result =0

while num >0:
    last_digit = num%10
    result= (result*10)+last_digit
    num= num//10

if n == result:
    print("Num is palindrome")

else:
    print("Not a Palindrom")
# Out:
# Num is palindrome
